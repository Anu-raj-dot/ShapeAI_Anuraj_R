# %%
## IMPORTING DATASET
from keras.datasets import mnist
 
data = mnist.load_data()

# %%
(X_train, y_train), (X_test, y_test) = data

# %%
# Shape of Training Data
X_train[0].shape
# Out:
# (28, 28)

# %%
X_train.shape
# Out:
# (60000, 28, 28)

# %%
 # Reshape the Training data
X_train = X_train.reshape((X_train.shape[0], 28*28)).astype('float32') 
X_test = X_test.reshape((X_test.shape[0], 28*28)).astype('float32')

# %%
# Normalizing values from 0-255 to 0-1
X_train = X_train / 255
X_test = X_test / 255

# %%
from keras.utils import np_utils
 
print(y_test.shape)
 
y_train = np_utils.to_categorical(y_train)
y_test = np_utils.to_categorical(y_test)
 
num_classes = y_test.shape[1]
print(y_test.shape)
# Out:
# (10000,)
# (10000, 10)

# %%
from keras.models import Sequential
from keras.layers import Dense

# %%
model = Sequential()
 
model.add(Dense(32, input_dim = 28*28, activation='relu'))
 
model.add(Dense(64, activation='relu'))
 
model.add(Dense(10, activation='softmax'))

# %%
# Compile Model
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
# print Model summary
model.summary()
# Out:
# Model: "sequential_19"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_57 (Dense)             (None, 32)                25120
# _________________________________________________________________
# dense_58 (Dense)             (None, 64)                2112
# _________________________________________________________________
# dense_59 (Dense)             (None, 10)                650
# =================================================================
# Total params: 27,882
# Trainable params: 27,882
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Train Model
model.fit(X_train, y_train, epochs=10, batch_size=100)
# Out:
# Epoch 1/10
# 600/600 [==============================] - 2s 2ms/step - loss: 0.8065 - accuracy: 0.7686
# Epoch 2/10
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1965 - accuracy: 0.9427
# Epoch 3/10
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1448 - accuracy: 0.9571
# Epoch 4/10
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1181 - accuracy: 0.9639
# Epoch 5/10
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1030 - accuracy: 0.9691
# Epoch 6/10
# 600/600 [==============================] - 1s 2ms/step - loss: 0.0872 - accuracy: 0.9735
# Epoch 7/10
# 600/600 [==============================] - 1s 2ms/step - loss: 0.0797 - accuracy: 0.9761
# Epoch 8/10
# 600/600 [==============================] - 1s 2ms/step - loss: 0.0718 - accuracy: 0.9788
# Epoch 9/10
# 600/600 [==============================] - 1s 2ms/step - loss: 0.0634 - accuracy: 0.9801
# Epoch 10/10
# 600/600 [==============================] - 1s 2ms/step - loss: 0.0593 - accuracy: 0.9820

# %%
scores = model.evaluate(X_test, y_test)
print(scores)
# Out:
# 313/313 [==============================] - 0s 1ms/step - loss: 0.1043 - accuracy: 0.9681
# [0.104290671646595, 0.9681000113487244]
